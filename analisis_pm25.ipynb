# %% [markdown]
# <a href="https://colab.research.google.com/github/arelyleal-m/tesis-zmvm-pm-clima-salud/blob/main/analisis_pm25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
